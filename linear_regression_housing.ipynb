# %% [markdown]
# <a href="https://colab.research.google.com/github/udshah31/ml_assignment/blob/main/linear_regression_housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets

# %%
housing = datasets.fetch_california_housing()

# %%
housing
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
print(housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block group
#         - HouseAge      median house age in block group
#         - AveRooms      average number of rooms per household
#         - AveBedrms     average number of bedrooms per household
#         - Population    block group population
#         - AveOccup      average number of household members
#         - Latitude      block group latitude
#         - Longitude     block group longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# ...

# %%
print(housing.feature_names)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
X = housing.data
Y = housing.target

# %%
X.shape, Y.shape
# Out:
# ((20640, 8), (20640,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size= 0.2)

# %%
X_train.shape, Y_train.shape
# Out:
# ((16512, 8), (16512,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((4128, 8), (4128,))

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y_test, Y_pred))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y_test, Y_pred))
# Out:
# Coefficients: [ 4.36419326e-01  9.57421844e-03 -1.08117849e-01  6.34255172e-01
#  -3.37639775e-06 -8.22313742e-03 -4.15940908e-01 -4.28283345e-01]
# Intercept: -36.36495004219629
# Mean squared error (MSE): 0.54
# Coefficient of determination (R^2): 0.60

# %%
print(housing.feature_names)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
r2_score(Y_test, Y_pred)
# Out:
# 0.5964131157144394

# %%
r2_score(Y_test, Y_pred).dtype
# Out:
# dtype('float64')

# %%
'%.2f' % 0.523810833536016
# Out:
# '0.52'

# %%
import seaborn as sns

# %%
Y_test
# Out:
# array([0.943  , 5.00001, 2.425  , ..., 2.809  , 1.275  , 1.109  ])

# %%
import numpy as np
np.array(Y_test)
# Out:
# array([0.943  , 5.00001, 2.425  , ..., 2.809  , 1.275  , 1.109  ])

# %%
Y_pred
# Out:
# array([1.21115686, 3.54585231, 2.26164514, ..., 1.94093917, 1.24633407,
#        1.60228693])

# %%
import matplotlib.pyplot as plt

plt.scatter(Y_test, Y_pred)

plt.show()

# %%
import seaborn as sns
sns.scatterplot(x=Y_test, y=Y_pred, marker="+")
# Out:
# <Axes: >

# %%
sns.scatterplot(x=Y_test, y=Y_pred, alpha=1)
# Out:
# <Axes: >
